# %%
def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 9)

def check_winner(board, player):
    # Check rows, columns and diagonals for a win
    for i in range(3):
        if all([spot == player for spot in board[i]]):  # row
            return True
        if all([board[j][i] == player for j in range(3)]):  # column
            return True
    if all([board[i][i] == player for i in range(3)]):  # diagonal
        return True
    if all([board[i][2 - i] == player for i in range(3)]):  # other diagonal
        return True
    return False

def tic_tac_toe():
    board = [[" " for _ in range(3)] for _ in range(3)]
    current_player = "X"
    moves = 0

    while moves < 9:
        print_board(board)
        print(f"Player {current_player}, make your move (row and column: 0, 1, or 2).")

        try:
            row = int(input("Row: "))
            col = int(input("Column: "))
        except ValueError:
            print("Invalid input. Please enter numbers 0, 1, or 2.")
            continue

        if row not in [0,1,2] or col not in [0,1,2]:
            print("Invalid row or column. Please enter 0, 1, or 2.")
            continue

        if board[row][col] != " ":
            print("That spot is already taken. Try another one.")
            continue

        board[row][col] = current_player
        moves += 1

        if check_winner(board, current_player):
            print_board(board)
            print(f"Player {current_player} wins!")
            return

        current_player = "O" if current_player == "X" else "X"

    print_board(board)
    print("It's a tie!")

# Run the game
tic_tac_toe()
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player X, make your move (row and column: 0, 1, or 2).
# Row: 2
# Column: 3
# Invalid row or column. Please enter 0, 1, or 2.
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player X, make your move (row and column: 0, 1, or 2).
# Row: 2
# Column: 0
#   |   |
# ---------
#   |   |
# ---------
# X |   |
# ---------
# Player O, make your move (row and column: 0, 1, or 2).
# Row: 1
# Column: 1
#   |   |
# ---------
#   | O |
# ---------
# X |   |
# ---------
# Player X, make your move (row and column: 0, 1, or 2).
# Row: 2
# Column: 1
#   |   |
# ---------
#   | O |
# ---------
# X | X |
# ---------
# Player O, make your move (row and column: 0, 1, or 2).
# Row: 0
# Column: 0
# O |   |
# ---------
#   | O |
# ---------
# X | X |
# ---------
# Player X, make your move (row and column: 0, 1, or 2).
# Row: 2
# Column: 1
# That spot is already taken. Try another one.
# O |   |
# ---------
#   | O |
# ---------
# X | X |
# ---------
# Player X, make your move (row and column: 0, 1, or 2).
# Row: 2
# Column: 2
# O |   |
# ---------
#   | O |
# ---------
# X | X | X
# ---------
# Player X wins!
